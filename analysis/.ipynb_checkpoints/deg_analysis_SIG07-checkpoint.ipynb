# %%
import numpy as np
import scanpy as sc
import anndata as ad
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
import warnings
plt.rcParams['figure.dpi'] = 100
plt.rcParams['savefig.dpi'] = 300

# %% [markdown]
# # Import Data

# %%
adata = ad.read_h5ad('/data/rudensky/EYW/SIG07/scanpy_outs/SIG07_doublets_CR_RNA_zscore.h5ad')

# %%
# replace linker-1 and linker-2 with just linker
adata.obs['ligand_call_oBC_CR'] = adata.obs['ligand_call_oBC_CR'].str.replace(
    r'linker-(1|2)', 'linker', regex=True)
print(adata.obs['ligand_call_oBC_CR'].unique())
# Out:
# ['IL4_linker' 'IL4_IL12' 'IL12_IFNA' 'IL4_IFNA' 'IL12_linker' 'IL12_IL6'
#  'IL2_TNF' 'IL21_linker' 'IFNA_linker' 'IL2_linker' 'IL2_IL6' 'IL4_IL6'
#  'TNF_linker' 'IL2_IL12' 'IL2_IL4' 'IFNA_TNF' 'IL6_linker' 'IL4_IL21'
#  'IL4_IL27' 'linker_linker' 'IL27_linker' 'IL27_TNF' 'IFNA_IL27'
#  'IL6_IL21' 'IL2_IL27' 'IL4_TNF' 'IL6_TNF' 'IL2_IL21' 'IL6_IFNA'
#  'IL6_IL27' 'IL2_IFNA' 'IL21_TNF' 'IFNA_IL21' 'IL21_IL27' 'IL12_TNF'
#  'IL12_IL27' 'IL12_IL21']

# %% [markdown]
# # Scanpy DEG

# %% [markdown]
# First, we'll use a simple non-parametric wilcoxon test to calculate DEGs. Starting with the simple first.

# %%
warnings.simplefilter(action='ignore',category=pd.errors.PerformanceWarning)
sc.tl.rank_genes_groups(adata, 'ligand_call_oBC_CR',
                        reference='linker_linker',
                        method='wilcoxon',
                        pts=True)

# %%
degWilcox = sc.get.rank_genes_groups_df(adata, group=None)
degWilcoxSig = sc.get.rank_genes_groups_df(adata, group=None, pval_cutoff=0.1)

# %%
degWilcox.to_csv("/data/rudensky/EYW/git_projects/SIG07/analysis_outs/deg_wilcoxon.csv")
degWilcoxSig.to_csv("/data/rudensky/EYW/git_projects/SIG07/analysis_outs/deg_sig_wilcoxon.csv")

# %%
degWilcox
# Out:
#              group    names     scores  logfoldchanges  pvals  pvals_adj  \
# 0        IFNA_IL21    Isg15  49.412685        6.643268    0.0        0.0
# 1        IFNA_IL21     Zbp1  49.240025        3.773547    0.0        0.0
# 2        IFNA_IL21    Ifit3  49.117832        7.043824    0.0        0.0
# 3        IFNA_IL21    Stat1  49.020500        3.406465    0.0        0.0
# 4        IFNA_IL21   Rnf213  48.447807        4.917690    0.0        0.0
# ...            ...      ...        ...             ...    ...        ...
# 375835  TNF_linker     Ighm -40.574741       -1.111760    0.0        0.0
# 375836  TNF_linker   Sh2d2a -41.809788       -1.661366    0.0        0.0
# 375837  TNF_linker  Selenop -42.546642       -1.387298    0.0        0.0
# 375838  TNF_linker    S1pr1 -44.089268       -1.627957    0.0        0.0
# 375839  TNF_linker    Pdcd4 -47.536823       -1.118161    0.0        0.0
#
#         pct_nz_group
# 0           0.962675
# 1           0.991446
# 2           0.956454
# ...

# %%
import pandas as pd

def calculate_logFC_and_compare(df, group_a, group_b, p_val=0.1):
    """
    Calculate logFC of group A + logFC of group B and compare to logFC of group C.
    Include all genes significant in A, B, or C.

    Args:
    df (pd.DataFrame): DataFrame containing the data with columns ['group', 'names', 'logfoldchanges', 'pvals_adj'].
    group_a (str): Category name for group A.
    group_b (str): Category name for group B.

    Returns:
    pd.DataFrame: DataFrame with calculated values and significance comparison.
    """
    # Derive group C
    ligands = sorted([group_a, group_b])
    possible_group_c = [f"{ligands[0]}_{ligands[1]}", f"{ligands[1]}_{ligands[0]}"]
    # Check which of the possible group C values exists in the dataset
    group_c = next((group for group in possible_group_c if group in df['group'].unique()), None)
    if group_c is None:
        raise ValueError(f"Neither '{possible_group_c[0]}' nor '{possible_group_c[1]}' found in the dataset.")

    # Filter DataFrame for groups A, B, and C
    df_a = df[df['group'] == f"{group_a}_linker"].set_index('names')
    df_b = df[df['group'] == f"{group_b}_linker"].set_index('names')
    df_c = df[df['group'] == group_c].set_index('names')

    # Merge dataframes to align genes
    merged = df_a[['logfoldchanges', 'pvals_adj']].rename(columns={'logfoldchanges': f"logFC_{group_a}", 'pvals_adj': f"pvals_adj_{group_a}"}).join(
        df_b[['logfoldchanges', 'pvals_adj']].rename(columns={'logfoldchanges': f"logFC_{group_b}", 'pvals_adj': f"pvals_adj_{group_b}"}), how='outer'
    ).join(
        df_c[['logfoldchanges', 'pvals_adj']].rename(columns={'logfoldchanges': f"logFC_{group_c}", 'pvals_adj': f"pvals_adj_{group_c}"}), how='outer'
    )

    # Calculate logFC_A + logFC_B
    merged['logFC_expected'] = merged[f"logFC_{group_a}"] + merged[f"logFC_{group_b}"]
    
    # Calculate comparison logFC_C - (logFC_A + logFC_B)
    merged['logFC_difference'] = merged[f"logFC_{group_c}"] - merged['logFC_expected']
    
    # Determine significance
    # Filter for significant genes
    merged['significant'] = merged[[f"pvals_adj_{group_a}", f"pvals_adj_{group_b}", f"pvals_adj_{group_c}"]].min(axis=1) < p_val
    significant_genes = merged[merged['significant']].drop(columns='significant')
    
    return significant_genes.reset_index()

# %%
calculate_logFC_and_compare(degWilcox, "IL4","IL27")
# Out:
#          names  logFC_IL4  pvals_adj_IL4  logFC_IL27  pvals_adj_IL27  \
# 0     AI467606  -0.051968   6.631017e-01    0.162115        0.002889
# 1     AU040320  -0.110735   3.506622e-01   -0.121687        0.220717
# 2         Aacs   0.833412   1.022668e-10    0.160539        0.512051
# 3         Aak1   0.171632   4.438783e-05    0.150086        0.000299
# 4         Aar2   0.545547   4.706458e-02    0.250076        0.703490
# ...        ...        ...            ...         ...             ...
# 5658    mt-Nd3   0.110401   3.039345e-02   -0.030282        0.702840
# 5659    mt-Nd4   0.074999   2.936487e-03   -0.011286        0.829069
# 5660   mt-Nd4l   0.104462   1.307780e-04    0.033410        0.577431
# 5661    mt-Nd5   0.065658   2.263864e-03    0.012590        0.726358
# 5662    mt-Nd6   0.075357   4.676299e-02    0.047884        0.349366
#
#       logFC_IL4_IL27  pvals_adj_IL4_IL27  logFC_expected  logFC_difference
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

def compare_logfc_and_plot(deg_df, group_a, group_b, group_c):
    """
    Calculate the sum of log fold changes (logFC) for group_a and group_b, compare it to group_c,
    and create a scatter plot of logFC_A_plus_B vs. logFC_C.

    Parameters:
    - deg_df: DataFrame containing differential expression data with columns ['group', 'names', 'logfoldchanges'].
    - group_a: Name of group A in the 'group' column.
    - group_b: Name of group B in the 'group' column.
    - group_c: Name of group C in the 'group' column.

    Returns:
    - DataFrame with genes, logFC_A, logFC_B, logFC_A_plus_B, logFC_C, and the difference.
    """
    # Filter the DataFrame for the relevant groups
    deg_a = deg_df[deg_df['group'] == group_a][['names', 'logfoldchanges']].rename(columns={'logfoldchanges': 'logFC_A'})
    deg_b = deg_df[deg_df['group'] == group_b][['names', 'logfoldchanges']].rename(columns={'logfoldchanges': 'logFC_B'})
    deg_c = deg_df[deg_df['group'] == group_c][['names', 'logfoldchanges']].rename(columns={'logfoldchanges': 'logFC_C'})

    # Merge the data for the three groups on gene names
    merged_df = deg_a.merge(deg_b, on='names', how='outer').merge(deg_c, on='names', how='outer')

    # Calculate the sum of logFC for A and B
    merged_df['logFC_A_plus_B'] = merged_df['logFC_A'] + merged_df['logFC_B']

    # Calculate the difference between logFC_A_plus_B and logFC_C
    merged_df['difference'] = merged_df['logFC_A_plus_B'] - merged_df['logFC_C']

    # Create a scatter plot
    plt.figure(figsize=(8, 6))
    sns.scatterplot(
        x=merged_df['logFC_A_plus_B'],
        y=merged_df['logFC_C'],
        hue=merged_df['difference'],  # Optional: Color by the difference
        palette='coolwarm',
        alpha=0.7
    )
    plt.axline((0, 0), slope=1, color='grey', linestyle='--', linewidth=1)  # Add y=x reference line
    plt.title(f'Scatter Plot: logFC_A_plus_B vs. logFC_C\n({group_a} + {group_b} vs. {group_c})')
    plt.xlabel('logFC_A_plus_B (A + B)')
    plt.ylabel('logFC_C (C)')
    plt.legend(title='Difference', loc='best')
    plt.grid(True)
    plt.tight_layout()
    plt.show()

    return merged_df

# Example usage
# Assuming 'deg' is your DataFrame:
# result_df = compare_logfc_and_plot(deg, 'IFNA_linker-1', 'TNF_linker-1', 'IFNA_TNF')

# %%
df = compare_logfc_and_plot(degSig, 'IL4_linker-1','IL27_linker-1','IL4_IL27').sort_values(by='difference', ascending=False)

# %%
df
# Out:
#         names   logFC_A   logFC_B   logFC_C  logFC_A_plus_B  difference
# 4612    Tgtp1  2.287890  3.298662  3.641980        5.586552    1.944572
# 4307    Socs1  4.773899  2.037249  5.034862        6.811148    1.776286
# 2084     Igtp  1.715586  2.947333  3.045030        4.662919    1.617889
# 2177    Irgm2  0.989103  2.526800  2.015144        3.515903    1.500759
# 479      Bcl6 -1.013765  0.964906 -1.308561       -0.048859    1.259702
# ...       ...       ...       ...       ...             ...         ...
# 5429   mt-Nd3  0.137330       NaN       NaN             NaN         NaN
# 5430   mt-Nd4  0.091395       NaN       NaN             NaN         NaN
# 5431  mt-Nd4l  0.103171       NaN  0.104934             NaN         NaN
# 5432   mt-Nd5  0.076839       NaN       NaN             NaN         NaN
# 5433   mt-Nd6  0.097279       NaN       NaN             NaN         NaN
#
# [5434 rows x 6 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

def identify_and_plot_unique_degs(deg_df, group_a, group_b, group_c):
    """
    Identify DEGs unique to group_c (not present in group_a or group_b), and create a scatter plot.

    Parameters:
    - deg_df: DataFrame containing differential expression data with columns ['group', 'names', 'logfoldchanges'].
    - group_a: Name of group A in the 'group' column.
    - group_b: Name of group B in the 'group' column.
    - group_c: Name of group C in the 'group' column.

    Returns:
    - DataFrame with genes unique to group_c and a scatter plot showing logFC_A_plus_B vs. logFC_C.
    """
    # Filter the DataFrame for the relevant groups
    deg_a = deg_df[deg_df['group'] == group_a][['names', 'logfoldchanges']].rename(columns={'logfoldchanges': 'logFC_A'})
    deg_b = deg_df[deg_df['group'] == group_b][['names', 'logfoldchanges']].rename(columns={'logfoldchanges': 'logFC_B'})
    deg_c = deg_df[deg_df['group'] == group_c][['names', 'logfoldchanges']].rename(columns={'logfoldchanges': 'logFC_C'})

    # Merge the data for A and B
    merged_ab = deg_a.merge(deg_b, on='names', how='outer')

    # Find genes unique to group C (not present in A or B)
    unique_to_c = deg_c[~deg_c['names'].isin(merged_ab['names'])]

    # Optional: Create a scatter plot of unique DEGs (logFC_A_plus_B vs. logFC_C)
    plt.figure(figsize=(8, 6))
    sns.scatterplot(
        x=[0] * len(unique_to_c),  # A + B logFC is 0 for unique genes
        y=unique_to_c['logFC_C'],
        color='red',
        alpha=0.7,
        label='Unique to Group C'
    )
    plt.axhline(0, color='grey', linestyle='--', linewidth=1)  # Reference line at logFC_C=0
    plt.title(f'Unique DEGs in Group C\n({group_c} not in {group_a} or {group_b})')
    plt.xlabel('logFC_A_plus_B (A + B)')
    plt.ylabel('logFC_C (C)')
    plt.legend(loc='best')
    plt.grid(True)
    plt.tight_layout()
    plt.show()

    return unique_to_c

# Example usage
# Assuming 'deg' is your DataFrame:
# unique_genes = identify_and_plot_unique_degs(deg, 'IFNA_linker-1', 'TNF_linker-1', 'IFNA_TNF')
# print(unique_genes)

# %%
temp = identify_and_plot_unique_degs(degSig, 'IL6_linker-1','IL27_linker-1','IL6_IL27').sort_values('logFC_C')

# %%
temp.to_csv("/data/rudensky/EYW/git_projects/SIG07/analysis_outs/temp.csv")

# %%
degSigSum = degSig['group'].value_counts()
degSigSum = degSigSum[degSigSum > 0]

# %%
degSigSum
# Out:
# group
# IL2_TNF          6680
# IL4_TNF          6480
# IL6_TNF          6148
# IL2_IL4          5563
# IL21_TNF         5518
# IL2_IL6          5297
# IFNA_TNF         5274
# IL2_IL21         5243
# IL4_IL6          5158
# IL27_TNF         5145
# IL2_linker-1     5057
# IL2_IL27         4972
# TNF_linker-1     4813
# TNF_linker-2     4666
# IL4_IL27         4660
# IL4_IFNA         4636
# IL2_IFNA         4627
# IL2_linker-2     4617
# IL4_IL21         4514
# IFNA_IL27        4183
# IL6_IL21         4142
# IL4_linker-2     4054
# IL6_IFNA         4042
# IL4_linker-1     4030
# IL2_IL12         3950
# IL12_TNF         3899
# IL6_linker-1     3894
# IL6_linker-2     3719
# IL6_IL27         3710
# IFNA_IL21        3635
# IL4_IL12         3627
# IL12_IFNA        3377
# IFNA_linker-1    3327
# IL21_IL27        3212
# IFNA_linker-2    2911
# IL12_IL21        2293
# IL12_IL6         2168
# IL27_linker-1    2126
# IL12_IL27        2116
# IL27_linker-2    2060
# IL21_linker-1    2050
# ...

# %%
degSig[degSig['group']=='IL6_linker-1']
# Out:
#                group   names     scores  logfoldchanges          pvals  \
# 120537  IL6_linker-1  Igfbp4  53.245628        3.698430   0.000000e+00
# 120538  IL6_linker-1    Bcl3  49.884083        2.823927   0.000000e+00
# 120539  IL6_linker-1   Sbno2  45.522781        2.852257   0.000000e+00
# 120540  IL6_linker-1   Il21r  45.353622        2.234011   0.000000e+00
# 120541  IL6_linker-1   Socs3  44.670197        3.966010   0.000000e+00
# ...              ...     ...        ...             ...            ...
# 124426  IL6_linker-1    Smc4 -26.566547       -0.866675  1.653887e-155
# 124427  IL6_linker-1  Shisa5 -26.921648       -0.570571  1.225520e-159
# 124428  IL6_linker-1    Grap -29.299517       -1.287719  1.051926e-188
# 124429  IL6_linker-1    Mxd4 -29.616671       -1.477343  9.116389e-193
# 124430  IL6_linker-1   Pdcd4 -34.060604       -1.034673  2.827546e-254
#
#             pvals_adj
# 120537   0.000000e+00
# 120538   0.000000e+00
# 120539   0.000000e+00
# ...

# %%
IFNA = degSig[degSig['group']=='IFNA_linker-1'].set_index('names')
TNF = degSig[degSig['group']=='TNF_linker-1'].set_index('names')

# %%
df = pd.DataFrame('expected_LFC' = (IFNA['logfoldchanges'] + TNF['logfoldchanges']))
# Out:
#   Cell In[33], line 1
#     df = pd.DataFrame('expected_LFC' = (IFNA['logfoldchanges'] + TNF['logfoldchanges']))
#                       ^
# SyntaxError: expression cannot contain assignment, perhaps you meant "=="?
